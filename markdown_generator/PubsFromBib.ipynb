# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    # "proceeding": {
    #     "file" : "proceedings.bib",
    #     "venuekey": "booktitle",
    #     "venue-pretext": "In the proceedings of ",
    #     "collection" : {"name":"publications",
    #                     "permalink":"/publication/"}
        
    # },
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
bibdata.entries
# Out:
# OrderedCaseInsensitiveDict([('2021ApJ...922..237W', Entry('article',
#   fields=[
#     ('title', '{GRB 210121A: A Typical Fireball Burst Detected by Two Small Missions}'),
#     ('journal', '\\apj'),
#     ('keywords', 'Gamma-ray bursts, 629, Astrophysics - High Energy Astrophysical Phenomena'),
#     ('year', '2021'),
#     ('month', 'December'),
#     ('volume', '922'),
#     ('number', '2'),
#     ('eid', '237'),
#     ('pages', '237'),
#     ('doi', '10.3847/1538-4357/ac29bd'),
#     ('archivePrefix', 'arXiv'),
#     ('eprint', '2107.10452'),
#     ('primaryClass', 'astro-ph.HE'),
#     ('adsurl', 'https://ui.adsabs.harvard.edu/abs/2021ApJ...922..237W'),
#     ('adsnote', 'Provided by the SAO/NASA Astrophysics Data System')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{Wang}, Xiangyu Ivy'), Person('{Zheng}, Xutao'), Person('{Xiao}, Shuo'), Person('{Yang}, Jun'), Person('{Liu}, Zi-Ke'), Person('{Yang}, Yu-Han'), Person('{Zou}, Jin-Hang'), Person('{Zhang}, Bin-Bin'), Person('{Zeng}, Ming'), Person('{Xiong}, Shao-Lin'), Person('{Feng}, Hua'), Person('{Song}, Xin-Ying'), Person('{Wen}, Jiaxing'), Person('{Xu}, Dacheng'), Person('{Chen}, Guo-Yin'), Person('{Ni}, Yang'), Person('{Zhang}, Zi-Jian'), Person('{Wu}, Yu-Xuan'), Person('{Cai}, Ce'), Person('{Cang}, Jirong'), Person('{Deng}, Yun-Wei'), Person('{Gao}, Huaizhong'), Person('{Kong}, De-Feng'), Person('{Huang}, Yue'), Person('{Li}, Cheng-Kui'), Person('{Li}, Hong'), Person('{Li}, Xiao-Bo'), Person('{Liang}, En-Wei'), Person('{Lin}, Lin'), Person('{Liu}, Yihui'), Person('{Long}, Xiangyun'), Person('{Lu}, Dian'), Person('{Luo}, Qi'), Person('{Ma}, Yong-Chang'), Person('{Meng}, Yan-Zhi'), Person('{Peng}, Wen-Xi'), Person('{Qiao}, Rui'), Person('{Song}, Li-Ming'), Person('{Tian}, Yang'), Person('{Wang}, Pei-Yuan'), Person('{Wang}, Ping'), Person('{Wang}, Xiang-Gao'), Person('{Xu}, Sheng'), Person('{Yang}, Dongxin'), Person('{Yin}, Yi-Han'), Person('{Zeng}, Weihe'), Person('{Zeng}, Zhi'), Person('{Zhang}, Ting-Jun'), Person('{Zhang}, Yuchong'), Person('{Zhang}, Zhao'), Person('{Zhang}, Zhen')])]))), ('2022PrA....40..506Z', Entry('article',
#   fields=[
#     ('title', "{The Research of the Milky Way's Accretion and Merger Origin}"),
#     ('journal', 'Progress in Astronomy'),
#     ('keywords', 'Milky Way evolution, accretion, merger, stellar stream'),
#     ('year', '2022'),
#     ('month', 'December'),
#     ('volume', '40'),
#     ('pages', '506-534'),
#     ('doi', '10.3969/j.issn.1000-8349.2022.04.02'),
#     ('adsurl', 'https://ui.adsabs.harvard.edu/abs/2022PrA....40..506Z'),
#     ('adsnote', 'Provided by the SAO/NASA Astrophysics Data System')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{Zhang}, Zi-jian'), Person('{Zhao}, Gang')])]))), ('2023RAA....23k5023Z', Entry('article',
#   fields=[
#     ('title', '{GRB 220408B: A Three-episode Burst from a Precessing Jet}'),
#     ('journal', 'Research in Astronomy and Astrophysics'),
#     ('keywords', 'gamma-rays: general, (stars:) gamma-ray burst: individual (GRB 220408B), stars: jets, Astrophysics - High Energy Astrophysical Phenomena'),
#     ('year', '2023'),
#     ('month', 'November'),
#     ('volume', '23'),
#     ('number', '11'),
#     ('eid', '115023'),
#     ('pages', '115023'),
#     ('doi', '10.1088/1674-4527/acfa59'),
#     ('archivePrefix', 'arXiv'),
#     ('eprint', '2302.03215'),
#     ('primaryClass', 'astro-ph.HE'),
#     ('adsurl', 'https://ui.adsabs.harvard.edu/abs/2023RAA....23k5023Z'),
#     ('adsnote', 'Provided by the SAO/NASA Astrophysics Data System')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{Zhang}, Zijian'), Person('{Iris Yin}, Yi-Han'), Person('{Wang}, Chenyu'), Person('{Ivy Wang}, Xiangyu'), Person('{Yang}, Jun'), Person('{Meng}, Yan-Zhi'), Person('{Liu}, Zi-Ke'), Person('{Chen}, Guo-Yin'), Person('{Fu}, Xiaoping'), Person('{Gao}, Huaizhong'), Person('{Li}, Sihao'), Person('{Liu}, Yihui'), Person('{Long}, Xiangyun'), Person('{Ma}, Yong-Chang'), Person('{Pan}, Xiaofan'), Person('{Sun}, Yuanze'), Person('{Wu}, Wei'), Person('{Yang}, Zirui'), Person('{Ye}, Zhizhen'), Person('{Yu}, Xiaoyu'), Person('{Zhao}, Shuheng'), Person('{Zheng}, Xutao'), Person('{Zhou}, Tao'), Person('{Tang}, Qing-Wen'), Person('{Yan}, Qiurong'), Person('{Zhou}, Rong'), Person('{Wang}, Zhonghai'), Person('{Feng}, Hua'), Person('{Zeng}, Ming'), Person('{Zhang}, Bin-Bin')])]))), ('2023ApJ...954..159Z', Entry('article',
#   fields=[
#     ('title', '{XMM-Newton Observations of Two Archival X-Ray Weak Type 1 Quasars: Obscuration Induced X-Ray Weakness and Variability}'),
#     ('journal', '\\apj'),
#     ('keywords', 'Galaxies, Active galaxies, Quasars, X-ray active galactic nuclei, 573, 17, 1319, 2035, Astrophysics - Astrophysics of Galaxies, Astrophysics - High Energy Astrophysical Phenomena'),
#     ('year', '2023'),
#     ('month', 'September'),
#     ('volume', '954'),
#     ('number', '2'),
#     ('eid', '159'),
#     ('pages', '159'),
#     ('doi', '10.3847/1538-4357/ace7c2'),
#     ('archivePrefix', 'arXiv'),
#     ('eprint', '2307.07554'),
#     ('primaryClass', 'astro-ph.GA'),
#     ('adsurl', 'https://ui.adsabs.harvard.edu/abs/2023ApJ...954..159Z'),
#     ('adsnote', 'Provided by the SAO/NASA Astrophysics Data System')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{Zhang}, Zijian'), Person('{Luo}, Bin'), Person('{Brandt}, W. N.'), Person('{Du}, Pu'), Person('{Hu}, Chen'), Person('{Huang}, Jian'), Person('{Pu}, Xingting'), Person('{Wang}, Jian-Min'), Person('{Yi}, Weimin')])]))), ('2024ApJ...976...99S', Entry('article',
#   fields=[
#     ('title', '{GTC Optical/Near-infrared Upper Limits and NICER X-Ray Analysis of SGR J1935+2154 for the Outburst in 2022}'),
#     ('journal', '\\apj'),
#     ('keywords', 'Magnetars, Neutron stars, Soft gamma-ray repeaters, X-ray bursts, X-ray transient sources, 992, 1108, 1471, 1814, 1852, Astrophysics - High Energy Astrophysical Phenomena'),
#     ('year', '2024'),
#     ('month', 'November'),
#     ('volume', '976'),
#     ('number', '1'),
#     ('eid', '99'),
#     ('pages', '99'),
#     ('doi', '10.3847/1538-4357/ad822f'),
#     ('archivePrefix', 'arXiv'),
#     ('eprint', '2410.00635'),
#     ('primaryClass', 'astro-ph.HE'),
#     ('adsurl', 'https://ui.adsabs.harvard.edu/abs/2024ApJ...976...99S'),
#     ('adsnote', 'Provided by the SAO/NASA Astrophysics Data System')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{Shao}, Yi-Xuan'), Person('{Zhou}, Ping'), Person('{Li}, Xiang-Dong'), Person('{Zhang}, Bin-Bin'), Person('{Castro-Tirado}, Alberto Javier'), Person('{Wang}, Pei'), Person('{Li}, Di'), Person('{Zhang}, Zeng-Hua'), Person('{Zhang}, Zi-Jian'), Person('{Hu}, You-Dong'), Person('{Pandey}, Shashi B.')])]))), ('2025ApJ...979..107H', Entry('article',
#   fields=[
#     ('title', '{Photometric Selection of Type 1 Quasars in the XMM-LSS Field with Machine Learning and the Disk{\\textendash}Corona Connection}'),
#     ('journal', '\\apj'),
#     ('keywords', 'Quasars, X-ray surveys, 1319, 1824, Astrophysics - Astrophysics of Galaxies'),
#     ('year', '2025'),
#     ('month', 'February'),
#     ('volume', '979'),
#     ('number', '2'),
#     ('eid', '107'),
#     ('pages', '107'),
#     ('doi', '10.3847/1538-4357/ad9baf'),
#     ('archivePrefix', 'arXiv'),
#     ('eprint', '2412.06923'),
#     ('primaryClass', 'astro-ph.GA'),
#     ('adsurl', 'https://ui.adsabs.harvard.edu/abs/2025ApJ...979..107H'),
#     ('adsnote', 'Provided by the SAO/NASA Astrophysics Data System')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('{Huang}, Jian'), Person('{Luo}, Bin'), Person('{Brandt}, W. N.'), Person('{Chen}, Ying'), Person('{Ni}, Qingling'), Person('{Xue}, Yongquan'), Person('{Zhang}, Zijian')])])))])

# %%
pubkey = {'\\apj': 'The Astrophysical Journal',
'Research in Astronomy and Astrophysics': 'Research in Astronomy and Astrophysics',
'Progress in Astronomy':'Progress in Astronomy'
}

# %%
b['adsurl']
# Out:
# 'https://ui.adsabs.harvard.edu/abs/2025ApJ...979..107H'

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = pubkey[b['journal']]#publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."
            
            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + format_citation(citation) + "'"   #html_escape(citation)
            md += "\nads_link: '" + b['adsurl'] + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            # if url:
            #     md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            # else:
            #     md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED 2021ApJ...922..237W: " {GRB 210121A: A Typical Fireball Burst Detected by Two Small ... "
# SUCESSFULLY PARSED 2022PrA....40..506Z: " {The Research of the Milky Way's Accretion and Merger Origin ... "
# SUCESSFULLY PARSED 2023RAA....23k5023Z: " {GRB 220408B: A Three-episode Burst from a Precessing Jet}  "
# SUCESSFULLY PARSED 2023ApJ...954..159Z: " {XMM-Newton Observations of Two Archival X-Ray Weak Type 1 Q ... "
# SUCESSFULLY PARSED 2024ApJ...976...99S: " {GTC Optical/Near-infrared Upper Limits and NICER X-Ray Anal ... "
# SUCESSFULLY PARSED 2025ApJ...979..107H: " {Photometric Selection of Type 1 Quasars in the XMM-LSS Fiel ... "

# %%
# Out:
# 'Huang J, Luo B, Brandt W, et al. The Astrophysical Journal, 2025'

# %%
import re

def format_author(author_str):
    """将单个作者格式化为姓氏+首字母的格式"""
    match = re.match(r'^\s*(.*?)\s*{\s*(.+?)\s*}\s*$', author_str)
    if not match:
        return None
    given_names = re.sub(r'[-.]', ' ', match.group(1).strip())
    surname = match.group(2).strip()
    initials = [part[0].upper() for part in re.split(r'\s+', given_names) if part]
    return f"{surname} {' '.join(initials)}"

def format_citation(input_str):
    """主处理函数"""
    # 预处理HTML转义字符
    input_str = input_str.replace('&quot;', '"')
    
    # 分割作者部分
    authors_end = input_str.find('"')
    authors_part = input_str[:authors_end].strip(' ,')
    remaining_str = input_str[authors_end+1:]
    
    # 分割标题部分
    title_end = remaining_str.find('"')
    title = remaining_str[:title_end]
    remaining_str = remaining_str[title_end+1:].strip()
    
    # 提取期刊信息
    journal_info = re.match(r'^([^,]+),\s*(\d{4})(.*)$', remaining_str)
    if not journal_info:
        return "Invalid format"
    
    journal = journal_info.group(1).strip()
    year = journal_info.group(2)
    vol_info = journal_info.group(3).strip(' ,.')
    
    # 处理作者列表
    authors = [a.strip() for a in authors_part.split(',') if a.strip()]
    formatted_authors = []
    for author in authors:
        fa = format_author(author)
        if fa: formatted_authors.append(fa)
    
    # 构建作者字符串
    if len(formatted_authors) > 3:
        authors_str = ', '.join(formatted_authors[:3]) + ', et al.'
    else:
        authors_str = ', '.join(formatted_authors)
    
    # 构建最终引用
    citation = f"{authors_str} {journal}, {year}"
    if vol_info:
        citation += f", {vol_info}"
    return citation

# 示例用法
input_str = ' Zijian {Zhang},  Bin {Luo},  W. {Brandt},  Pu {Du},  Chen {Hu},  Jian {Huang},  Xingting {Pu},  Jian-Min {Wang},  Weimin {Yi}, "XMM-Newton Observations of Two Archival X-Ray Weak Type 1 Quasars: Obscuration Induced X-Ray Weakness and Variability." The Astrophysical Journal, 2023, 954(2): 159.'
print(format_citation(input_str))
# Out:
# Zhang Z, Luo B, Brandt W, et al. The Astrophysical Journal, 2023, 954(2): 159
